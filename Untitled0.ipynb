# %% [markdown]
# <a href="https://colab.research.google.com/github/agneskaa/Gen-password/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Moduł 1

# %%
print ('Hello World!')

a = 1
b = 2
result = a/b

print (result)
# Out:
# Hello World!
# 0.5

# %%
# BMI = weight / height ^2

weight = 68 #kg
height = 1.58 #m
BMI = weight / (height**2)
BMI
# Out:
# 27.239224483255885

# %%
#Zadanie 1 Koszt kaw

price = 12.5
qty = 7
koszt = price * qty
print ("Koszt:", koszt, "PLN")
# Out:
# Koszt: 87.5 PLN

# %%
#Zadanie 2 Konwersje i typy

x = "3.14"
x = float (x) + 2

type(x)
# Out:
# float

# %% [markdown]
# # Moduł 2

# %%
d = True #bool
e = False

#and &

d & e

#or |

e | e

#not

not e
# Out:
# True
